# %% [markdown]
# ### **FUENTES**:
#
# PetFinder Kaggle:
#
# https://www.kaggle.com/competitions/petfinder-adoption-prediction/data
#
# First Tutorial:
#
# https://towardsdatascience.com/how-to-train-an-image-classifier-in-pytorch-and-use-it-to-perform-basic-inference-on-single-images-99465a1e9bf5
#
# Second Deep Tutorial:
#
# https://rumn.medium.com/part-1-ultimate-guide-to-fine-tuning-in-pytorch-pre-trained-model-and-its-configuration-8990194b71e
#
# Logo Recognition API:
#
# https://heartbeat.comet.ml/logo-recognition-ios-application-using-machine-learning-and-flask-api-aec4eff3be11
#
# Hybrid (multimodal) neural network architecture : Combination of tabular, textual and image inputs:
#
# https://medium.com/@dave.cote.msc/hybrid-multimodal-neural-network-architecture-combination-of-tabular-textual-and-image-inputs-7460a4f82a2e
#
#
#
# ### **INDICACIONES PREVIAS**:
#
# + **Git**:
#     + Clonamos el repo: root de todos los repos y ponemos git clone "url_repo"
#     + Hacemos el checkout de la rama main: git checkout -b new-branch
#
# + **Poetry**:
#     + Instalamos poetry: https://python-poetry.org/docs/
#     + Realizamos un Update del pyproject: poetry update
#     + Activamos el entorno que creo poetry: poetry shell
#     + Intentamos correr una celda, si nos pide seleccionar el environment y no lo vemos en la lista, cerrar y volver abrir VSC
#
# + **Torch y CUDA**:
#     + Verificar que versión pide torch:
#         + Versión de torch instalada: poetry show (en mi caso la 1.13.1)
#         + Buscar la versión correspondiente en la documentación: https://pytorch.org/get-started/previous-versions/  (en mi caso el 11.7)
#     + Instalar CUDA para Torch (buscar la versión correspondiente de CUDA): https://developer.nvidia.com/cuda-11-7-0-download-archive
#     + Verificar que CUDA esté funcional: correr en una celda torch.cuda.is_available()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install optuna
! pip install kaleido
# Out:
# Collecting optuna
#   Downloading optuna-3.6.1-py3-none-any.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 4.5 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.2-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.0/233.0 kB 7.6 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.2 colorlog-6.8.2 optuna-3.6.1
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 10.5 MB/s eta 0:00:00
# Installing collected packages: kaleido
# Successfully installed kaleido-0.2.1

# %%
! mkdir -p "/content/input/petfinder-adoption-prediction"
! cp "/content/drive/MyDrive/Colab Notebooks/laboratorio 2/petfinder-adoption-prediction.zip"  "/content/input/petfinder-adoption-prediction/petfinder-adoption-prediction.zip"

# %%
! unzip -u "/content/input/petfinder-adoption-prediction/petfinder-adoption-prediction.zip" -d "/content/input/petfinder-adoption-prediction"
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a89bfa0aa.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a89d4e8f3.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a89f8b241.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a89fd1f1e.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8a1d4151.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8a2aecc3.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8a3c4f49.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8a8f95f6.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8b358af2.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8b9d57b4.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8ba4dfa1.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8c19a325.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8c336257.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8c555240.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8cdba660.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8ce7d647.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8cfb849e.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8cfbf446.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8d14470d.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8d44452c.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8d9108c4.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8da358d1.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8de0737e.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8df693c0.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8e4a881b.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8e5ae23a.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8e6ad61c.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8e79c8c4.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8ea0c6a7.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8eed143b.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8f17e0de.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8f2a5210.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8f43bea5.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a8f735068.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a90161422.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a904d6da4.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a906ff5f5.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a9085cdde.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a9092993a.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a90a72141.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a90c3dbd7.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a90d6fbee.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a90da3a12.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a91141912.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a91761e54.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a9199119d.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a92258c0e.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a927d96ba.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a9294a9ea.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a929a9f48.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a92b06d0f.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/a92c2f233.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/
json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/fe9e5aa06.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/fea00b643.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/fea8ba32e.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/fea9183f6.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/feb06d776.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/fed21411c.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/fed3c719a.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/fed43b600.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/fed799a78.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/fee0b4da6.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/fee500b95.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/fee5e43b2.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/feec7a438.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/fef340804.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/fef6df98c.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/fefb3826e.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/feff505f1.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff05d4438.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff065ec7b.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff0b61121.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff10041de.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff125cf8d.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff127e4d3.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff14c3dbe.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff1613693.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff16e6dad.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff2224b9d.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff22356ef.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff2cf88a0.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff361d3b6.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff3d455a0.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff43926c3.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff47b9a27.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff498c903.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff4b9b3b4.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff4d9a3c6.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff50c6171.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff5158511.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff5e30380.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff5ea4f84.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff601e5ec.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff6118cc2.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff618d36f.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff6ff53c4.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff706f8cc.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff7707a35.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff78347b7.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff7d25ffb.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff7ff0f3c.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff832cb7e.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff85f13d7.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff867121e.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff873a820.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff891d6b6.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff8e4c708.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff8e7c016.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff96988fc.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff9ce365b.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff9d8cb25.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ff9f62e79.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ffa5c6c35.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ffaa73202.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ffab93d18.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ffb315803.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ffb33c204.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ffb3a78e1.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ffb6a7f5d.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ffbc3eaaf.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ffd2e82a9.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ffd506899.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ffd61a488.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ffd697903.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ffdad97e5.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ffe0f06ab.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ffe2090b3.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ffe5a0271.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ffe7f0b70.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ffebad2e7.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/ffef9a2af.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/fff24fcb5.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/fff4a6420.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/fff6f2f61.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/fffd78a11.json
#   inflating: /content/input/petfinder-adoption-prediction/train_sentiment/fffd9b5a8.json

# %%
! mkdir -p "/content/UA_MDM_LDI_II/work"
! mkdir -p "/content/drive/MyDrive/Colab Notebooks/laboratorio 2/work/optuna_temp_artifacts"
! mkdir -p "/content/drive/MyDrive/Colab Notebooks/laboratorio 2/work/optuna_artifacts"
! mkdir -p "/content/UA_MDM_LDI_II/work/train_images_classes"
! mkdir -p "/content/UA_MDM_LDI_II/work/val_images_classes"

# %%
! mkdir -p "/content/UA_MDM_LDI_II/tutoriales"
! cp "/content/drive/MyDrive/Colab Notebooks/laboratorio 2/utils.py"  "/content/UA_MDM_LDI_II/tutoriales/utils.py"

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, cohen_kappa_score
import os
import shutil
import time
import copy
import datetime
from tqdm import tqdm
#import matplotlib.pyplot as plt
#import seaborn as sns
#import cv2
#from PIL import Image
#from pathlib import Path

import optuna
from optuna.artifacts import FileSystemArtifactStore, upload_artifact

import torch
import torchvision.models as models
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
import torch.nn.functional as F

from joblib import load, dump

from UA_MDM_LDI_II.tutoriales.utils import plot_confusion_matrix
# Verificamos que CUDA está funcional
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# **Seteo el Modelo**
#
# Teoría de Resnet: https://towardsdatascience.com/introduction-to-resnets-c0a830a288a4

# %%
# Importo modelo ResNet entrenado en Imagenet
resnet50 = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
# Modificar la última capa para adaptarse a tu problema específico
num_ftrs = resnet50.fc.in_features
resnet50.fc = torch.nn.Linear(num_ftrs, 5) # Clasificación 5 clases
# Configuro para usar cuda si está disponible
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
resnet50 = resnet50.to(device)
# Instancio del criterio de pérdida CrossEntropyLoss
criterion = nn.CrossEntropyLoss()
# Instancio Stochastic Gradient Descent (SGD): Defino el parámetro del Learning Rate (define "el paso" en que avanzan los pesos en cada iteración) y el Momentum (pone innercia a la dirección del gradiente descendiente para que no cambie de dirección en minimos locales)
optimizer = optim.SGD(resnet50.parameters(), lr=0.001, momentum=0.9) # Parámetros default del SGD
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 63.5MB/s]

# %% [markdown]
# **Seteo parámetros, directorios y funciones**

# %%
# Paths
BASE_DIR = './'
PATH_TO_TRAIN = os.path.join(BASE_DIR, "input/petfinder-adoption-prediction/train/train.csv")
PATH_TO_IMAGES_DIR = os.path.join(BASE_DIR, "input/petfinder-adoption-prediction/train_images")
#PATH_TO_TEMP_FILES = os.path.join(BASE_DIR, "UA_MDM_LDI_II/work/optuna_temp_artifacts")
#PATH_TO_OPTUNA_ARTIFACTS = os.path.join(BASE_DIR, "UA_MDM_LDI_II/work/optuna_artifacts")
PATH_TO_TEMP_FILES = "/content/drive/MyDrive/Colab Notebooks/laboratorio 2/work/optuna_temp_artifacts"
PATH_TO_OPTUNA_ARTIFACTS = "/content/drive/MyDrive/Colab Notebooks/laboratorio 2/work/optuna_artifacts"

MODEL_NAME = '04 ResNet'

MODEL_VERSION = '1.0.0'

# Parametros y variables
CREATE_PYTORCH_DIRECTORIES = 1
SEED = 42
BATCH_SIZE = 80 #50 #ver la ram libre
TEST_SIZE = 0.2
IMAGE_SIZE = 299
CPU_CORES = os.cpu_count()

# Armo el nuevo directorio de train
new_train_directory = os.path.join(BASE_DIR, 'UA_MDM_LDI_II/work/train_images_classes')
os.makedirs(new_train_directory, exist_ok=True) # si ya existe el nombre, lo deja como está

# Armo el nuevo directorio de validación
new_val_directory = os.path.join(BASE_DIR, 'UA_MDM_LDI_II/work/val_images_classes')
os.makedirs(new_val_directory, exist_ok=True)

# Definir las clases ordenadas
class_names = ['0', '1', '2', '3', '4']

# Mapear las etiquetas de las clases a números enteros consecutivos
class_to_idx = {class_name: i for i, class_name in enumerate(class_names)}

# Creo las carpetas de clases dentro de los directorios
for clase in class_names: # Una para cada clase
   os.makedirs(os.path.join(new_train_directory, str(clase)), exist_ok=True)
   os.makedirs(os.path.join(new_val_directory, str(clase)), exist_ok=True)

# %%
import gc
import torch

# Liberar explícitamente todas las variables de GPU
#del model
#del optimizer
#del criterion
#del dataloaders
#del datasets
#del inputs, labels, outputs, loss

# Llamar al recolector de basura
gc.collect()

# Vaciar la memoria caché de CUDA
torch.cuda.empty_cache()

# %% [markdown]
# # Funciones para la carga y el preproceso
# def resize_to_square(im):
#     old_size = im.shape[:2] # old_size is in (height, width) format
#     # Calcula el factor de escala necesario para redimensionar la imagen de manera que el lado más largo tenga el tamaño deseado
#     ratio = float(IMAGE_SIZE)/max(old_size)
#     # Calcula las nuevas dimensiones de la imagen
#     new_size = tuple([int(x*ratio) for x in old_size])
#     # Redimensiona la imagen con el nuevo tamaño
#     im = cv2.resize(im, (new_size[1], new_size[0]))
#     # Calcula las diferencias de tamaño y agrega pixeles (color negro) en los extremos para que quede centrada y cuadrada
#     delta_w = IMAGE_SIZE - new_size[1]
#     delta_h = IMAGE_SIZE - new_size[0]
#     top, bottom = delta_h//2, delta_h-(delta_h//2)
#     left, right = delta_w//2, delta_w-(delta_w//2)
#     color = [0, 0, 0]
#     new_image = cv2.copyMakeBorder(im, top, bottom, left, right, cv2.BORDER_CONSTANT,value=color)
#     return new_image
#
#
# def load_image(pet_id):
#     path_to_image = os.path.join(PATH_TO_IMAGES_DIR, f'{pet_id}-1.jpg') # Irá a la primera imagen de la mascota
#     image = cv2.imread(path_to_image)
#     # Convierte la imagen de BGR a RGB porque estos modelos esperan ese orden de canales
#     image = cv2.convertScaleAbs(image)
#     image= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#     new_image = resize_to_square(image)
#     return new_image

# %%
def visualize_pet(pet_id):
    path_to_image = os.path.join(PATH_TO_IMAGES_DIR, f'{pet_id}-1.jpg') # Irá a la primera imagen de la mascota
    # Cargar la imagen
    image_to_show = cv2.imread(path_to_image)
    # Convertir a formato RGB
    image_to_show = cv2.cvtColor(image_to_show, cv2.COLOR_BGR2RGB)
    # Visualizar la imagen
    plt.imshow(image_to_show)
    plt.axis('off')  # No mostrar los ejes
    plt.show()

def visualize_image(image):
    # Convierte la imagen a un formato de enteros (CV_8U)
    image = cv2.convertScaleAbs(image)
    image= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    # Visualizar la imagen
    plt.imshow(image.astype(np.uint8))
    plt.axis('off')  # No mostrar los ejes
    plt.show()

# %% [markdown]
# **Cargo y Proceso Data**
#
# Nota: Pytorch necesita que estén las imágenes en los distintos directorios según su clase y su participación en el training

# %%
# Cargo
train_df = pd.read_csv(PATH_TO_TRAIN)

# Split para validación
train_data, val_data = train_test_split(train_df,
                               test_size = TEST_SIZE,
                               random_state = SEED,
                               stratify = train_df.AdoptionSpeed)




if CREATE_PYTORCH_DIRECTORIES == 1: # Poner en 0 si ya tengo las carpetas train_images_classes y val_images_classes con las imágenes copiadas
    # Función para copiar las imágenes a los directorios correspondientes
    def copy_imag(data, directorio_destino):
        for index, row in data.iterrows():
            petID = row['PetID']
            adoption_speed = row['AdoptionSpeed']

            # Nombre del archivo de imagen
            nombre_archivo = f"{petID}-1.jpg"

            # Ruta completa de la imagen de origen
            ruta_origen = os.path.join(PATH_TO_IMAGES_DIR, nombre_archivo)

            # Ruta completa del directorio de destino
            ruta_destino = os.path.join(directorio_destino, str(adoption_speed), nombre_archivo)

            # Verificar si el archivo de origen existe
            if os.path.exists(ruta_origen):
                # Copiar el archivo de origen al directorio de destino
                shutil.copy2(ruta_origen, ruta_destino)
        print("Completada la copia a: ",str(directorio_destino))

    # Copiar las imágenes al directorio de train
    copy_imag(train_data, new_train_directory)

    # Copiar las imágenes al directorio de val
    copy_imag(val_data, new_val_directory)

    print("Proceso completado.")
# Out:
# Completada la copia a:  ./UA_MDM_LDI_II/work/train_images_classes
# Completada la copia a:  ./UA_MDM_LDI_II/work/val_images_classes
# Proceso completado.

# %%
# Genero los DataLoaders
def create_dataloaders(train_directory, val_directory, batch_size, num_workers):
    # Transformaciones de imagen para el conjunto de entrenamiento
    train_transforms = transforms.Compose([
        transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])

    # Transformaciones de imagen para el conjunto de validación (sin data augment)
    val_transforms = transforms.Compose([
        transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])

    # Crear conjuntos de datos para el conjunto de entrenamiento y validación
    conjunto_entrenamiento = datasets.ImageFolder(train_directory, transform=train_transforms)
    conjunto_validacion = datasets.ImageFolder(val_directory, transform=val_transforms)

    # Asignar las clases ordenadas al conjunto de datos
    conjunto_entrenamiento.class_to_idx = {class_name: i for i, class_name in enumerate(class_names)}
    conjunto_validacion.class_to_idx = {class_name: i for i, class_name in enumerate(class_names)}

    # Crear dataloaders para el conjunto de entrenamiento y validación
    train_dataloader = torch.utils.data.DataLoader(conjunto_entrenamiento, batch_size=batch_size, shuffle=True, num_workers=num_workers)
    val_dataloader = torch.utils.data.DataLoader(conjunto_validacion, batch_size=batch_size, shuffle=False, num_workers=num_workers)

    return train_dataloader, val_dataloader

# Aplico las funcion de los DataLoaders
train_dataloader, val_dataloader = create_dataloaders(new_train_directory , new_val_directory , BATCH_SIZE, CPU_CORES)

# %%
#Genero una lista de PetIDs con imagen en el orden en que aparecen en el data loader
test_sample_ids = [i[0].split('/')[-1].split('-')[0] for i in val_dataloader.dataset.samples]

# %% [markdown]
# **Entreno**

# %%
def train_val(model, criterion, optimizer, dataloaders, datasets, device, num_epochs=20, lr=0.001, momentum = 0.9 ,trial=None):

    # Instancio Stochastic Gradient Descent (SGD): Defino el parámetro del Learning Rate (define "el paso" en que avanzan los pesos en cada iteración) y el Momentum (pone innercia a la dirección del gradiente descendiente para que no cambie de dirección en minimos locales)
    optimizer = optim.SGD(resnet50.parameters(), lr=lr, momentum=momentum) # Parámetros default del SGD

    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_kappa =  -999

    train_losses = []
    val_losses = []

    try:
        previous_best = study.best_value
    except:
        previous_best = -999


    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        kappa_labels_true = []
        kappa_labels_predicted = []
        output_scores = []

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in tqdm(dataloaders[phase]):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Zero the parameter gradients
                optimizer.zero_grad()

                # Forward
                # Track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)



                    # Backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                    elif phase == 'val':
                        kappa_labels_true.extend(labels.cpu().numpy().tolist())
                        kappa_labels_predicted.extend(preds.cpu().numpy().tolist())
                        outputs_np = outputs.cpu().numpy()
                        output_scores.extend([outputs_np[i,:] for i in range(outputs_np.shape[0])])

                # Statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

                #END OF BATCH

            epoch_loss = running_loss / len(datasets[phase])
            epoch_acc = running_corrects.double() / len(datasets[phase])

            if phase == 'train':
                train_losses.append(epoch_loss)
                kappa_score = np.nan
            else:
                val_losses.append(epoch_loss)
                kappa_score = cohen_kappa_score(kappa_labels_true,
                                  kappa_labels_predicted,
                                  weights = 'quadratic')



            print(f'{phase.title()} Loss: {epoch_loss:.4f} Acc: {epoch_acc*100:.2f}% Kappa: {kappa_score:.3f}')

            # If this is the best Epoch so far -> Deep copy the model
            if phase == 'val' and kappa_score > best_kappa:
                best_acc = epoch_acc
                best_kappa = kappa_score
                best_model_wts = copy.deepcopy(model.state_dict())


                #Best Epoch within a trial and better than previous trials
                if trial is not None and best_kappa > previous_best:

                    #Save test dataset with predictions
                    predicted_filename = os.path.join(PATH_TO_TEMP_FILES,f'test_{trial.study.study_name}_{trial.number}.joblib')
                    predicted_df = pd.DataFrame({'PetID':test_sample_ids,
                                'pred':output_scores}).merge(val_data, on='PetID')
                    dump(predicted_df, predicted_filename)

                    #Generate and save CM
                    cm_filename = os.path.join(PATH_TO_TEMP_FILES,f'cm_{trial.study.study_name}_{trial.number}.jpg')
                    plot_confusion_matrix(kappa_labels_true,kappa_labels_predicted).write_image(cm_filename)

            #END OF PHASE

        #END OF EPOCH

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:.2f}%'.format(best_acc * 100))

    # Load best model weights
    model.load_state_dict(best_model_wts)

    # Save in optuna trial the best test dataset, cm and model weights
    if trial is not None and best_kappa > previous_best:
        upload_artifact(trial, predicted_filename, artifact_store)

        upload_artifact(trial, cm_filename, artifact_store)

        file_name = f'{MODEL_NAME}_{MODEL_VERSION}_{trial.number}.pth'
        model_path = os.path.join(PATH_TO_TEMP_FILES, file_name)
        torch.save(model, model_path) # Podemos guardar solo los pesos si queremos: best_model.state_dict()
        upload_artifact(trial, model_path, artifact_store)

    return model,best_kappa

best_model,_ = train_val(resnet50, criterion, optimizer,
                       dataloaders={'train': train_dataloader,
                                    'val': val_dataloader},
                       datasets={'train': train_data, 'val': val_data},
                       device=device,
                       num_epochs=4)
# Guardo el modelo
run_id = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
file_name = f'{MODEL_NAME}_{MODEL_VERSION}_{run_id}.pth'
model_path = os.path.join(PATH_TO_TEMP_FILES, file_name)
torch.save(best_model, model_path) # Podemos guardar solo los pesos si queremos: best_model.state_dict()
print(f'Modelo guardado en {model_path}')
# Out:
# Epoch 0/3
# ----------
# 100%|██████████| 147/147 [03:41<00:00,  1.50s/it]
# Train Loss: 1.4350 Acc: 29.98% Kappa: nan
# 100%|██████████| 37/37 [00:24<00:00,  1.53it/s]
# Val Loss: 1.3926 Acc: 33.34% Kappa: 0.246
# Epoch 1/3
# ----------
#  42%|████▏     | 62/147 [01:34<02:07,  1.50s/it]

# %%
artifact_store = FileSystemArtifactStore(base_path=PATH_TO_OPTUNA_ARTIFACTS)


def optuna_train(trial):

    epochs = trial.suggest_int('epochs', 5, 5)

    lr = trial.suggest_float('lr', 0.00001, 0.1, log=True)

    momentum = trial.suggest_float('momentum', 0.0, 0.95)

    _,best_score = train_val(resnet50, criterion, optimizer,
                       dataloaders={'train': train_dataloader,
                                    'val': val_dataloader},
                       datasets={'train': train_data, 'val': val_data},
                       device=device,
                       num_epochs=epochs,
                       lr=lr,
                       momentum = momentum,
                       trial=trial)


    return(best_score)

# %%
! pip install kaleido

# %%
study = optuna.create_study(direction='maximize',
                            #storage="sqlite:///db.sqlite3",  # Specify the storage URL here.
                            storage="sqlite:////content/drive/MyDrive/Colab Notebooks/laboratorio 2/work/db.sqlite3",  # Specify the storage URL here.
                            study_name=f'{MODEL_NAME}_{MODEL_VERSION}',
                            load_if_exists = True)
study.optimize(optuna_train, n_trials=30)

# %%
# Utilizar esto para continuar con el trabajo previo de optimización

import optuna

# Reanudar el estudio existente
study = optuna.create_study(direction='maximize',
                            #storage="sqlite:///db.sqlite3",  # Specify the storage URL here.
                            storage="sqlite:////content/drive/MyDrive/Colab Notebooks/laboratorio 2/work/db.sqlite3",  # Specify the storage URL here.
                            study_name=f'{MODEL_NAME}_{MODEL_VERSION}',
                            load_if_exists=True)

# Obtener el número de ensayos completados
completed_trials = len(study.trials)
print(f"Ensayos completados: {completed_trials}")

# Definir el número de ensayos restantes
remaining_trials = 30 - completed_trials
print(f"Ensayos restantes: {remaining_trials}")

# Continuar la optimización con los ensayos restantes
if remaining_trials > 0:
    study.optimize(optuna_train, n_trials=remaining_trials)
else:
    print("Todos los ensayos completados.")
